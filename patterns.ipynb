# %%
#determining a number is even or odd
a=int(input())
b=a%2
c=b==0
if c:
    print("a is even")
else:
    print("a is odd")
# Out:
# 6
# a is even

# %%
a=10
print(id(a))
a=11
print(id(a))
# Out:
# 2119298411088
# 2119298411120

# %%
a=False
if a==True:
    print("a is true")
print("a is false")
# Out:
# a is false

# %%
n=int(input())
i=2
flag=False
while (i<n):
    if(n%i==0):
        flag=True
    i=i+1
if flag:
     print("n is not prime")
else:
    print("n is prime")
# Out:
# 8
# n is not prime

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n):
        print("*",end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# ****
# ****
# ****
# ****

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n):
        print(n,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 5
# 55555
# 55555
# 55555
# 55555
# 55555

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n):
        print(i,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 5
# 11111
# 22222
# 33333
# 44444
# 55555

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n):
        print(j,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# 1234
# 1234
# 1234
# 1234

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n):
        print(n-j+1,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 5
# 54321
# 54321
# 54321
# 54321
# 54321

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    p=i
    while(j<=n):
        print(p,end="")
        p=p+1
        j=j+1
    i=i+1
    print()
# Out:
# 5
# 12345
# 23456
# 34567
# 45678
# 56789

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=i):
        print(i,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# 1
# 22
# 333
# 4444

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=i):
        print(j,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# 1
# 12
# 123
# 1234

# %%
n=int(input())
i=1
p=1
while(i<=n):
    j=1
    while(j<=i):
        print(p,end="")
        p=p+1
        j=j+1
    i=i+1
    print()
# Out:
# 4
# 1
# 23
# 456
# 78910

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    p=i
    while(j<=i):
        print(p,end="")
        p=p+1
        j=j+1
    i=i+1
    print()
# Out:
# 4
# 1
# 23
# 345
# 4567

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n):
        print(chr(64+j),end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# ABCD
# ABCD
# ABCD
# ABCD

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n):
        print(chr(64+i),end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# AAAA
# BBBB
# CCCC
# DDDD

# %%
N=int(input())
i=1
while(i<=N):
    j=1
    while(i<=j):
        print(j,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15864/3998029945.py in <module>
#       4     j=1
#       5     while(i<=j):
# ----> 6         print(j,end="")
#       7         j=j+1
#       8     i=i+1
#
# C:\anaconda navigator\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# C:\anaconda navigator\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
# ...

# %%
N=int(input())
i=0
while(i<=N):
    j=1
    while(j<n-i+1):
        print(j,end="")
        j=j+1
    i=i+1
    print()
# Out:
# 4
# 1234
# 123
# 12
# 1

# %%
n=int(input())
i=1
while(i<=n):
    j=1
    while(j<=n-i):
        print("",end="")
        j=j+1
    k=1
    while(k<=i):
        print("1",end="")
        k=k+1
    i=i+1
    print()
# Out:
# 4
# 1
# 11
# 111
# 1111
